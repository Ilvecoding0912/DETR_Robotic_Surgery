# %% [markdown]
# <a href="https://colab.research.google.com/github/Ilvecoding0912/DETR_Robotic_Surgery/blob/main/DETR_training_v1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # DETR training process

# %% [markdown]
# Clone DETR Repo after changing to our dataset

# %%
# !git clone https://github.com/Ilvecoding0912/DETR_Robotic_Surgery.git
# %cd DETR_Robotic_Surgery
# Out:
# Cloning into 'DETR_Robotic_Surgery'...
# remote: Enumerating objects: 118, done.
# remote: Counting objects: 100% (38/38), done.
# remote: Compressing objects: 100% (37/37), done.
# remote: Total 118 (delta 10), reused 0 (delta 0), pack-reused 80
# Receiving objects: 100% (118/118), 2.46 MiB | 18.37 MiB/s, done.
# Resolving deltas: 100% (28/28), done.
# /content/DETR_Robotic_Surgery

# %% [markdown]
# Download DETR weights

# %%
import gdown

url = 'https://drive.google.com/uc?id=1HV2Tit0CsVeYKHugjx8QxROPegQa3AV-'
gdown.download(url,'detr_weights.pth',quiet=True)
# Out:
# 'detr_weights.pth'

# %%
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# !pip -q install 'git+https://github.com/facebookresearch/segment-anything.git'
# Out:
# --2023-08-28 04:50:00--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_b_01ec64.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 13.227.219.59, 13.227.219.70, 13.227.219.33, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|13.227.219.59|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 375042383 (358M) [binary/octet-stream]
# Saving to: ‘sam_vit_b_01ec64.pth’
#
# sam_vit_b_01ec64.pt 100%[===================>] 357.67M  57.8MB/s    in 5.7s
#
# 2023-08-28 04:50:06 (62.7 MB/s) - ‘sam_vit_b_01ec64.pth’ saved [375042383/375042383]
#
#   Preparing metadata (setup.py) ... done
#   Building wheel for segment-anything (setup.py) ... done

# %%
# %cd /content/DETR_Robotic_Surgery
from collections import OrderedDict
import torch
from torch import nn
from typing import Dict, List
from util.misc import NestedTensor
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor
import torch.nn.functional as F
from models.position_encoding import build_position_encoding

class backboneSAM(nn.Module):

    def __init__(self, ):
        super().__init__()
        sam = sam_model_registry["vit_b"](checkpoint="sam_vit_b_01ec64.pth")
        #Freeze()
        sam.eval()
        for param in sam.image_encoder.parameters():
            param.requires_grad = False
        self.sam_encoder = sam.image_encoder


    def forward(self, tensor_list: NestedTensor):
        xs = OrderedDict()
        with torch.no_grad():
            xs['0'] = self.sam_encoder(tensor_list.tensors)
        # print('out sam encoder', xs['0'].shape)
        out: Dict[str, NestedTensor] = {}
        for name, x in xs.items():
            m = tensor_list.mask
            # print('m', m.shape)
            assert m is not None
            import torch.nn.functional as F
            mask = F.interpolate(m[None].float(), size=x.shape[-2:]).to(torch.bool)[0]
            # mask = F.upsample_nearest(m[None].float(),size=x.shape[-2:]).to(torch.bool)[0]
            # print('mobarak',name, x.shape, mask.shape)
            out[name] = NestedTensor(x, mask)
        return out

class Joiner(nn.Sequential):
    def __init__(self, backbone, position_embedding):
        super().__init__(backbone, position_embedding)

    def forward(self, tensor_list: NestedTensor):
        xs = self[0](tensor_list)
        out: List[NestedTensor] = []
        pos = []
        for name, x in xs.items():
            out.append(x)
            # position encoding
            pos.append(self[1](x).to(x.tensors.dtype))

        return out, pos

def build_backbone(args):
    position_embedding = build_position_encoding(args)
    train_backbone = args.lr_backbone > 0
    return_interm_layers = args.masks
    backbone = backboneSAM()#Backbone(args.backbone, train_backbone, return_interm_layers, args.dilation)
    model = Joiner(backbone, position_embedding)
    # model.num_channels = backbone.num_channels
    return model
# Out:
# /content/DETR_Robotic_Surgery

# %% [markdown]
# Part of content related to training in 'main.py'.
# (We ignore the evaluation part.)

# %%
# %cd /content/DETR_Robotic_Surgery
from main import get_args_parser
import argparse
import torch
import time
import random
import datetime
import json
from torch.utils.data import DataLoader, DistributedSampler
import util.misc as utils
from datasets import build_dataset, get_coco_api_from_dataset
from pathlib import Path
import numpy as np
from engine import evaluate, train_one_epoch
from models import build_model
from datasets.coco import *
import os

def main():

    parser = argparse.ArgumentParser('DETR training and evaluation script', parents=[get_args_parser()])
    args = parser.parse_args([])
    args.output_dir = './outputs' # Results dir
    args.endovis_path = 'endovis17' # Path to our dataset
    args.device = 'cuda' if torch.cuda.is_available() else 'cpu'
    # training parameters
    args.start_epoch = 0
    args.epochs = 50 # total number of epoch
    args.batch_size = 1

    # create output directoty if not exist
    if os.path.exists(args.output_dir) is False:
        os.mkdir(args.output_dir)

    utils.init_distributed_mode(args)
    print("git:\n  {}\n".format(utils.get_sha()))
    print(args)

    device = torch.device(args.device)

    # fix the seed for reproducibility
    seed = args.seed + utils.get_rank()
    torch.manual_seed(seed)
    np.random.seed(seed)
    random.seed(seed)

    # create model
    model, criterion, postprocessors = build_model(args)
    model.to(device)
    # print(model)
    model_without_ddp = model
    n_parameters = sum(p.numel() for p in model.parameters() if p.requires_grad)
    print('number of params:', n_parameters)

    param_dicts = [
        {"params": [p for n, p in model_without_ddp.named_parameters() if "backbone" not in n and p.requires_grad]},
        {
            "params": [p for n, p in model_without_ddp.named_parameters() if "backbone" in n and p.requires_grad],
            "lr": args.lr_backbone,
        },
    ]
    optimizer = torch.optim.AdamW(param_dicts, lr=args.lr,
                                    weight_decay=args.weight_decay)
    lr_scheduler = torch.optim.lr_scheduler.StepLR(optimizer, args.lr_drop)

    # Our dataset class (initialize in datasets->coco.py)
    dataset_train = EnvidosDataset(args.endovis_path, transforms=make_coco_transforms('train'), mode='train', length=4)

    if args.distributed:
        sampler_train = DistributedSampler(dataset_train)
    else:
        sampler_train = torch.utils.data.RandomSampler(dataset_train)

    batch_sampler_train = torch.utils.data.BatchSampler(
        sampler_train, args.batch_size, drop_last=True)

    data_loader_train = DataLoader(dataset_train, batch_sampler=batch_sampler_train,
                                    collate_fn=utils.collate_fn, num_workers=args.num_workers)

    #---------------------- Training Process ----------------------
    print("Start training")
    start_time = time.time()

    sam_backbone = build_backbone(args)#BackboneBase()
    sam_backbone.to(device)
    sam_backbone.eval()
    model_without_ddp.backbone = sam_backbone
    model_without_ddp.input_proj = nn.Conv2d(256, model_without_ddp.transformer.d_model, kernel_size=1)
    model_without_ddp.to(device)

    for epoch in range(args.start_epoch, args.epochs):
        if args.distributed:
            sampler_train.set_epoch(epoch)

        #----------------- main training function (can be seen in 'engine.py') -----------------
        train_stats = train_one_epoch(
            model_without_ddp, criterion, data_loader_train, optimizer, device, epoch,
            args.clip_max_norm)

        lr_scheduler.step()

        # Save trained models
        output_dir = Path(args.output_dir)
        if args.output_dir:
            checkpoint_paths = [output_dir / f'checkpoint{epoch:04}.pth']
            if (epoch + 1) % args.lr_drop == 0 or (epoch + 1) % 5 == 0:
                checkpoint_paths.append(output_dir / f'checkpoint{epoch:04}_lr{args.lr}.pth')
            for checkpoint_path in checkpoint_paths:
                utils.save_on_master({
                    'model': model_without_ddp.state_dict(),
                    'optimizer': optimizer.state_dict(),
                    'lr_scheduler': lr_scheduler.state_dict(),
                    'epoch': epoch,
                    'args': args,
                }, checkpoint_path)

        log_stats = {**{f'train_{k}': v for k, v in train_stats.items()},
                        'epoch': epoch,
                        'n_parameters': n_parameters}

        if args.output_dir and utils.is_main_process():
            with (output_dir / "log.txt").open("a") as f:
                f.write(json.dumps(log_stats) + "\n")


    total_time = time.time() - start_time
    total_time_str = str(datetime.timedelta(seconds=int(total_time)))
    print('Training time {}'.format(total_time_str))


main()
# Out:
# /content/DETR_Robotic_Surgery
# Not using distributed mode
# git:
#   sha: 620f6db10fc39148252ca1b758d02b916d9cdce1, status: has uncommited changes, branch: main
#
# Namespace(lr=0.0001, lr_backbone=1e-05, batch_size=1, weight_decay=0.0001, epochs=50, lr_drop=200, clip_max_norm=0.1, frozen_weights=None, model=True, backbone='resnet50', dilation=False, position_embedding='sine', enc_layers=6, dec_layers=6, dim_feedforward=2048, hidden_dim=256, dropout=0.1, nheads=8, num_queries=100, pre_norm=False, masks=False, aux_loss=True, set_cost_class=1, set_cost_bbox=5, set_cost_giou=2, mask_loss_coef=1, dice_loss_coef=1, bbox_loss_coef=5, giou_loss_coef=2, eos_coef=0.01, dataset_file='endovis17', coco_path=None, endovis_path='endovis17', coco_panoptic_path=None, remove_difficult=False, output_dir='./outputs', device='cuda', seed=42, resume='', start_epoch=0, eval=False, num_workers=2, world_size=1, dist_url='env://', distributed=False)
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:208: UserWarning: The parameter 'pretrained' is deprecated since 0.13 and may be removed in the future, please use 'weights' instead.
#   warnings.warn(
# /usr/local/lib/python3.10/dist-packages/torchvision/models/_utils.py:223: UserWarning: Arguments other than a weight enum or `None` for 'weights' are deprecated since 0.13 and may be removed in the future. The current behavior is equivalent to passing `weights=ResNet50_Weights.IMAGENET1K_V1`. You can also use `weights=ResNet50_Weights.DEFAULT` to get the most up-to-date weights.
#   warnings.warn(msg)
# number of params: 41281037
# Start training
# Epoch: [0]  [0/4]  eta: 0:00:04  lr: 0.000100  class_error: 66.67  loss: 31.3212 (31.3212)  loss_ce: 2.2468 (2.2468)  loss_bbox: 1.5440 (1.5440)  loss_giou: 0.9390 (0.9390)  loss_ce_0: 2.4712 (2.4712)  loss_bbox_0: 1.8375 (1.8375)  loss_giou_0: 1.2668 (1.2668)  loss_ce_1: 2.3951 (2.3951)  loss_bbox_1: 1.7656 (1.7656)  loss_giou_1: 1.2705 (1.2705)  loss_ce_2: 2.1937 (2.1937)  loss_bbox_2: 2.3438 (2.3438)  loss_giou_2: 1.4862 (1.4862)  loss_ce_3: 2.1639 (2.1639)  loss_bbox_3: 1.3836 (1.3836)  loss_giou_3: 1.2681 (1.2681)  loss_ce_4: 2.1586 (2.1586)  loss_bbox_4: 1.6999 (1.6999)  loss_giou_4: 0.8869 (0.8869)  loss_ce_unscaled: 2.2468 (2.2468)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.3088 (0.3088)  loss_giou_unscaled: 0.4695 (0.4695)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.4712 (2.4712)  loss_bbox_0_unscaled: 0.3675 (0.3675)  loss_giou_0_unscaled: 0.6334 (0.6334)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 2.3951 (2.3951)  loss_bbox_1_unscaled: 0.3531 (0.3531)  loss_giou_1_unscaled: 0.6353 (0.6353)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 2.1937 (2.1937)  loss_bbox_2_unscaled: 0.4688 (0.4688)  loss_giou_2_unscaled: 0.7431 (0.7431)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 2.1639 (2.1639)  loss_bbox_3_unscaled: 0.2767 (0.2767)  loss_giou_3_unscaled: 0.6340 (0.6340)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 2.1586 (2.1586)  loss_bbox_4_unscaled: 0.3400 (0.3400)  loss_giou_4_unscaled: 0.4435 (0.4435)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 1.2244  data: 0.2885  max mem: 9095
# Epoch: [0]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 30.8470 (32.0928)  loss_ce: 2.1716 (2.1763)  loss_bbox: 1.5440 (1.8115)  loss_giou: 0.9452 (1.3872)  loss_ce_0: 2.4925 (2.5289)  loss_bbox_0: 1.7314 (1.7765)  loss_giou_0: 1.2668 (1.2837)  loss_ce_1: 2.3951 (2.4161)  loss_bbox_1: 1.0714 (1.3579)  loss_giou_1: 1.0384 (1.0579)  loss_ce_2: 2.1937 (2.2327)  loss_bbox_2: 1.4107 (1.7983)  loss_giou_2: 1.0615 (1.3272)  loss_ce_3: 2.1880 (2.2138)  loss_bbox_3: 1.3864 (1.6568)  loss_giou_3: 1.2681 (1.4141)  loss_ce_4: 2.1586 (2.1900)  loss_bbox_4: 1.6999 (1.9210)  loss_giou_4: 1.2639 (1.5429)  loss_ce_unscaled: 2.1716 (2.1763)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.3088 (0.3623)  loss_giou_unscaled: 0.4726 (0.6936)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.4925 (2.5289)  loss_bbox_0_unscaled: 0.3463 (0.3553)  loss_giou_0_unscaled: 0.6334 (0.6419)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 2.3951 (2.4161)  loss_bbox_1_unscaled: 0.2143 (0.2716)  loss_giou_1_unscaled: 0.5192 (0.5289)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 2.1937 (2.2327)  loss_bbox_2_unscaled: 0.2821 (0.3597)  loss_giou_2_unscaled: 0.5308 (0.6636)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 2.1880 (2.2138)  loss_bbox_3_unscaled: 0.2773 (0.3314)  loss_giou_3_unscaled: 0.6340 (0.7070)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 2.1586 (2.1900)  loss_bbox_4_unscaled: 0.3400 (0.3842)  loss_giou_4_unscaled: 0.6320 (0.7714)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 0.9719  data: 0.0792  max mem: 9095
# Epoch: [0] Total time: 0:00:03 (0.9929 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 30.8470 (32.0928)  loss_ce: 2.1716 (2.1763)  loss_bbox: 1.5440 (1.8115)  loss_giou: 0.9452 (1.3872)  loss_ce_0: 2.4925 (2.5289)  loss_bbox_0: 1.7314 (1.7765)  loss_giou_0: 1.2668 (1.2837)  loss_ce_1: 2.3951 (2.4161)  loss_bbox_1: 1.0714 (1.3579)  loss_giou_1: 1.0384 (1.0579)  loss_ce_2: 2.1937 (2.2327)  loss_bbox_2: 1.4107 (1.7983)  loss_giou_2: 1.0615 (1.3272)  loss_ce_3: 2.1880 (2.2138)  loss_bbox_3: 1.3864 (1.6568)  loss_giou_3: 1.2681 (1.4141)  loss_ce_4: 2.1586 (2.1900)  loss_bbox_4: 1.6999 (1.9210)  loss_giou_4: 1.2639 (1.5429)  loss_ce_unscaled: 2.1716 (2.1763)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.3088 (0.3623)  loss_giou_unscaled: 0.4726 (0.6936)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.4925 (2.5289)  loss_bbox_0_unscaled: 0.3463 (0.3553)  loss_giou_0_unscaled: 0.6334 (0.6419)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 2.3951 (2.4161)  loss_bbox_1_unscaled: 0.2143 (0.2716)  loss_giou_1_unscaled: 0.5192 (0.5289)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 2.1937 (2.2327)  loss_bbox_2_unscaled: 0.2821 (0.3597)  loss_giou_2_unscaled: 0.5308 (0.6636)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 2.1880 (2.2138)  loss_bbox_3_unscaled: 0.2773 (0.3314)  loss_giou_3_unscaled: 0.6340 (0.7070)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 2.1586 (2.1900)  loss_bbox_4_unscaled: 0.3400 (0.3842)  loss_giou_4_unscaled: 0.6320 (0.7714)  cardinality_error_4_unscaled: 97.0000 (97.0000)
# Epoch: [1]  [0/4]  eta: 0:00:05  lr: 0.000100  class_error: 100.00  loss: 31.8473 (31.8473)  loss_ce: 1.9863 (1.9863)  loss_bbox: 1.7356 (1.7356)  loss_giou: 1.2876 (1.2876)  loss_ce_0: 2.2423 (2.2423)  loss_bbox_0: 2.3909 (2.3909)  loss_giou_0: 1.5800 (1.5800)  loss_ce_1: 2.1910 (2.1910)  loss_bbox_1: 2.0842 (2.0842)  loss_giou_1: 1.3090 (1.3090)  loss_ce_2: 2.1839 (2.1839)  loss_bbox_2: 1.3035 (1.3035)  loss_giou_2: 1.0150 (1.0150)  loss_ce_3: 2.1865 (2.1865)  loss_bbox_3: 1.4509 (1.4509)  loss_giou_3: 1.2912 (1.2912)  loss_ce_4: 2.0216 (2.0216)  loss_bbox_4: 2.1015 (2.1015)  loss_giou_4: 1.4864 (1.4864)  loss_ce_unscaled: 1.9863 (1.9863)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.3471 (0.3471)  loss_giou_unscaled: 0.6438 (0.6438)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.2423 (2.2423)  loss_bbox_0_unscaled: 0.4782 (0.4782)  loss_giou_0_unscaled: 0.7900 (0.7900)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 2.1910 (2.1910)  loss_bbox_1_unscaled: 0.4168 (0.4168)  loss_giou_1_unscaled: 0.6545 (0.6545)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 2.1839 (2.1839)  loss_bbox_2_unscaled: 0.2607 (0.2607)  loss_giou_2_unscaled: 0.5075 (0.5075)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 2.1865 (2.1865)  loss_bbox_3_unscaled: 0.2902 (0.2902)  loss_giou_3_unscaled: 0.6456 (0.6456)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 2.0216 (2.0216)  loss_bbox_4_unscaled: 0.4203 (0.4203)  loss_giou_4_unscaled: 0.7432 (0.7432)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 1.3184  data: 0.3627  max mem: 9095
# Epoch: [1]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 29.5746 (29.5616)  loss_ce: 1.9495 (1.9643)  loss_bbox: 1.1100 (1.3938)  loss_giou: 0.8332 (1.0153)  loss_ce_0: 2.0531 (2.1104)  loss_bbox_0: 2.3204 (2.3454)  loss_giou_0: 1.4359 (1.4597)  loss_ce_1: 2.0679 (2.0873)  loss_bbox_1: 1.8865 (1.9209)  loss_giou_1: 1.3090 (1.3325)  loss_ce_2: 2.1178 (2.1391)  loss_bbox_2: 1.1765 (1.1033)  loss_giou_2: 0.7296 (0.8314)  loss_ce_3: 2.0683 (2.0832)  loss_bbox_3: 1.4509 (1.5178)  loss_giou_3: 1.1491 (1.1877)  loss_ce_4: 1.9018 (1.9433)  loss_bbox_4: 1.4201 (1.7214)  loss_giou_4: 1.2692 (1.4049)  loss_ce_unscaled: 1.9495 (1.9643)  class_error_unscaled: 66.6667 (75.0000)  loss_bbox_unscaled: 0.2220 (0.2788)  loss_giou_unscaled: 0.4166 (0.5076)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.0531 (2.1104)  loss_bbox_0_unscaled: 0.4641 (0.4691)  loss_giou_0_unscaled: 0.7179 (0.7298)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 2.0679 (2.0873)  loss_bbox_1_unscaled: 0.3773 (0.3842)  loss_giou_1_unscaled: 0.6545 (0.6662)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 2.1178 (2.1391)  loss_bbox_2_unscaled: 0.2353 (0.2207)  loss_giou_2_unscaled: 0.3648 (0.4157)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 2.0683 (2.0832)  loss_bbox_3_unscaled: 0.2902 (0.3036)  loss_giou_3_unscaled: 0.5745 (0.5938)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.9018 (1.9433)  loss_bbox_4_unscaled: 0.2840 (0.3443)  loss_giou_4_unscaled: 0.6346 (0.7025)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 0.9765  data: 0.0953  max mem: 9095
# Epoch: [1] Total time: 0:00:03 (0.9964 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 29.5746 (29.5616)  loss_ce: 1.9495 (1.9643)  loss_bbox: 1.1100 (1.3938)  loss_giou: 0.8332 (1.0153)  loss_ce_0: 2.0531 (2.1104)  loss_bbox_0: 2.3204 (2.3454)  loss_giou_0: 1.4359 (1.4597)  loss_ce_1: 2.0679 (2.0873)  loss_bbox_1: 1.8865 (1.9209)  loss_giou_1: 1.3090 (1.3325)  loss_ce_2: 2.1178 (2.1391)  loss_bbox_2: 1.1765 (1.1033)  loss_giou_2: 0.7296 (0.8314)  loss_ce_3: 2.0683 (2.0832)  loss_bbox_3: 1.4509 (1.5178)  loss_giou_3: 1.1491 (1.1877)  loss_ce_4: 1.9018 (1.9433)  loss_bbox_4: 1.4201 (1.7214)  loss_giou_4: 1.2692 (1.4049)  loss_ce_unscaled: 1.9495 (1.9643)  class_error_unscaled: 66.6667 (75.0000)  loss_bbox_unscaled: 0.2220 (0.2788)  loss_giou_unscaled: 0.4166 (0.5076)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.0531 (2.1104)  loss_bbox_0_unscaled: 0.4641 (0.4691)  loss_giou_0_unscaled: 0.7179 (0.7298)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 2.0679 (2.0873)  loss_bbox_1_unscaled: 0.3773 (0.3842)  loss_giou_1_unscaled: 0.6545 (0.6662)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 2.1178 (2.1391)  loss_bbox_2_unscaled: 0.2353 (0.2207)  loss_giou_2_unscaled: 0.3648 (0.4157)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 2.0683 (2.0832)  loss_bbox_3_unscaled: 0.2902 (0.3036)  loss_giou_3_unscaled: 0.5745 (0.5938)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.9018 (1.9433)  loss_bbox_4_unscaled: 0.2840 (0.3443)  loss_giou_4_unscaled: 0.6346 (0.7025)  cardinality_error_4_unscaled: 97.0000 (97.0000)
# Epoch: [2]  [0/4]  eta: 0:00:05  lr: 0.000100  class_error: 66.67  loss: 27.1128 (27.1128)  loss_ce: 1.8904 (1.8904)  loss_bbox: 1.3571 (1.3571)  loss_giou: 1.1357 (1.1357)  loss_ce_0: 2.0045 (2.0045)  loss_bbox_0: 1.3705 (1.3705)  loss_giou_0: 1.1028 (1.1028)  loss_ce_1: 1.9119 (1.9119)  loss_bbox_1: 1.3680 (1.3680)  loss_giou_1: 1.0119 (1.0119)  loss_ce_2: 1.9794 (1.9794)  loss_bbox_2: 1.3466 (1.3466)  loss_giou_2: 1.0608 (1.0608)  loss_ce_3: 1.9843 (1.9843)  loss_bbox_3: 1.7669 (1.7669)  loss_giou_3: 1.0027 (1.0027)  loss_ce_4: 1.8762 (1.8762)  loss_bbox_4: 1.8036 (1.8036)  loss_giou_4: 1.1395 (1.1395)  loss_ce_unscaled: 1.8904 (1.8904)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.2714 (0.2714)  loss_giou_unscaled: 0.5678 (0.5678)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.0045 (2.0045)  loss_bbox_0_unscaled: 0.2741 (0.2741)  loss_giou_0_unscaled: 0.5514 (0.5514)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 1.9119 (1.9119)  loss_bbox_1_unscaled: 0.2736 (0.2736)  loss_giou_1_unscaled: 0.5059 (0.5059)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 1.9794 (1.9794)  loss_bbox_2_unscaled: 0.2693 (0.2693)  loss_giou_2_unscaled: 0.5304 (0.5304)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 1.9843 (1.9843)  loss_bbox_3_unscaled: 0.3534 (0.3534)  loss_giou_3_unscaled: 0.5013 (0.5013)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.8762 (1.8762)  loss_bbox_4_unscaled: 0.3607 (0.3607)  loss_giou_4_unscaled: 0.5698 (0.5698)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 1.2852  data: 0.3434  max mem: 9095
# Epoch: [2]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 27.1128 (27.3133)  loss_ce: 1.8889 (1.8630)  loss_bbox: 1.6317 (1.7060)  loss_giou: 1.1357 (1.2225)  loss_ce_0: 1.9616 (1.9638)  loss_bbox_0: 1.2579 (1.3295)  loss_giou_0: 0.9663 (1.0240)  loss_ce_1: 1.9119 (1.9152)  loss_bbox_1: 0.9795 (1.0763)  loss_giou_1: 0.8919 (0.9038)  loss_ce_2: 1.9417 (1.9754)  loss_bbox_2: 1.3466 (1.3291)  loss_giou_2: 1.0315 (0.9888)  loss_ce_3: 1.9470 (1.9501)  loss_bbox_3: 1.6165 (1.7728)  loss_giou_3: 1.1555 (1.1964)  loss_ce_4: 1.8762 (1.8711)  loss_bbox_4: 1.8625 (1.9788)  loss_giou_4: 1.1395 (1.2465)  loss_ce_unscaled: 1.8889 (1.8630)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.3263 (0.3412)  loss_giou_unscaled: 0.5678 (0.6112)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9616 (1.9638)  loss_bbox_0_unscaled: 0.2516 (0.2659)  loss_giou_0_unscaled: 0.4831 (0.5120)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 1.9119 (1.9152)  loss_bbox_1_unscaled: 0.1959 (0.2153)  loss_giou_1_unscaled: 0.4459 (0.4519)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 1.9417 (1.9754)  loss_bbox_2_unscaled: 0.2693 (0.2658)  loss_giou_2_unscaled: 0.5157 (0.4944)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 1.9470 (1.9501)  loss_bbox_3_unscaled: 0.3233 (0.3546)  loss_giou_3_unscaled: 0.5778 (0.5982)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.8762 (1.8711)  loss_bbox_4_unscaled: 0.3725 (0.3958)  loss_giou_4_unscaled: 0.5698 (0.6232)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 0.9892  data: 0.0914  max mem: 9095
# Epoch: [2] Total time: 0:00:04 (1.0240 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 27.1128 (27.3133)  loss_ce: 1.8889 (1.8630)  loss_bbox: 1.6317 (1.7060)  loss_giou: 1.1357 (1.2225)  loss_ce_0: 1.9616 (1.9638)  loss_bbox_0: 1.2579 (1.3295)  loss_giou_0: 0.9663 (1.0240)  loss_ce_1: 1.9119 (1.9152)  loss_bbox_1: 0.9795 (1.0763)  loss_giou_1: 0.8919 (0.9038)  loss_ce_2: 1.9417 (1.9754)  loss_bbox_2: 1.3466 (1.3291)  loss_giou_2: 1.0315 (0.9888)  loss_ce_3: 1.9470 (1.9501)  loss_bbox_3: 1.6165 (1.7728)  loss_giou_3: 1.1555 (1.1964)  loss_ce_4: 1.8762 (1.8711)  loss_bbox_4: 1.8625 (1.9788)  loss_giou_4: 1.1395 (1.2465)  loss_ce_unscaled: 1.8889 (1.8630)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.3263 (0.3412)  loss_giou_unscaled: 0.5678 (0.6112)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9616 (1.9638)  loss_bbox_0_unscaled: 0.2516 (0.2659)  loss_giou_0_unscaled: 0.4831 (0.5120)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 1.9119 (1.9152)  loss_bbox_1_unscaled: 0.1959 (0.2153)  loss_giou_1_unscaled: 0.4459 (0.4519)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 1.9417 (1.9754)  loss_bbox_2_unscaled: 0.2693 (0.2658)  loss_giou_2_unscaled: 0.5157 (0.4944)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 1.9470 (1.9501)  loss_bbox_3_unscaled: 0.3233 (0.3546)  loss_giou_3_unscaled: 0.5778 (0.5982)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.8762 (1.8711)  loss_bbox_4_unscaled: 0.3725 (0.3958)  loss_giou_4_unscaled: 0.5698 (0.6232)  cardinality_error_4_unscaled: 97.0000 (97.0000)
# Epoch: [3]  [0/4]  eta: 0:00:05  lr: 0.000100  class_error: 66.67  loss: 24.7109 (24.7109)  loss_ce: 1.9137 (1.9137)  loss_bbox: 1.4381 (1.4381)  loss_giou: 1.1743 (1.1743)  loss_ce_0: 1.9817 (1.9817)  loss_bbox_0: 1.0463 (1.0463)  loss_giou_0: 0.8687 (0.8687)  loss_ce_1: 1.8704 (1.8704)  loss_bbox_1: 0.7608 (0.7608)  loss_giou_1: 0.6553 (0.6553)  loss_ce_2: 1.8710 (1.8710)  loss_bbox_2: 1.2936 (1.2936)  loss_giou_2: 0.8999 (0.8999)  loss_ce_3: 1.8077 (1.8077)  loss_bbox_3: 1.6429 (1.6429)  loss_giou_3: 0.9430 (0.9430)  loss_ce_4: 1.7548 (1.7548)  loss_bbox_4: 1.5771 (1.5771)  loss_giou_4: 1.2117 (1.2117)  loss_ce_unscaled: 1.9137 (1.9137)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.2876 (0.2876)  loss_giou_unscaled: 0.5872 (0.5872)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9817 (1.9817)  loss_bbox_0_unscaled: 0.2093 (0.2093)  loss_giou_0_unscaled: 0.4344 (0.4344)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 1.8704 (1.8704)  loss_bbox_1_unscaled: 0.1522 (0.1522)  loss_giou_1_unscaled: 0.3276 (0.3276)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 1.8710 (1.8710)  loss_bbox_2_unscaled: 0.2587 (0.2587)  loss_giou_2_unscaled: 0.4499 (0.4499)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 1.8077 (1.8077)  loss_bbox_3_unscaled: 0.3286 (0.3286)  loss_giou_3_unscaled: 0.4715 (0.4715)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.7548 (1.7548)  loss_bbox_4_unscaled: 0.3154 (0.3154)  loss_giou_4_unscaled: 0.6058 (0.6058)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 1.2759  data: 0.3444  max mem: 9095
# Epoch: [3]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 20.8841 (22.2782)  loss_ce: 1.9031 (1.8963)  loss_bbox: 1.0826 (1.1032)  loss_giou: 0.7027 (0.8009)  loss_ce_0: 2.0033 (2.0546)  loss_bbox_0: 0.9056 (0.9361)  loss_giou_0: 0.8056 (0.7781)  loss_ce_1: 1.8704 (1.8943)  loss_bbox_1: 0.7434 (0.7836)  loss_giou_1: 0.6700 (0.6912)  loss_ce_2: 1.8810 (1.9193)  loss_bbox_2: 0.8901 (1.0766)  loss_giou_2: 0.7320 (0.7871)  loss_ce_3: 1.8936 (1.9040)  loss_bbox_3: 0.6992 (1.0168)  loss_giou_3: 0.5374 (0.7105)  loss_ce_4: 1.8266 (1.8270)  loss_bbox_4: 0.9447 (1.1969)  loss_giou_4: 0.7517 (0.9017)  loss_ce_unscaled: 1.9031 (1.8963)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.2165 (0.2206)  loss_giou_unscaled: 0.3513 (0.4004)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.0033 (2.0546)  loss_bbox_0_unscaled: 0.1811 (0.1872)  loss_giou_0_unscaled: 0.4028 (0.3890)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 1.8704 (1.8943)  loss_bbox_1_unscaled: 0.1487 (0.1567)  loss_giou_1_unscaled: 0.3350 (0.3456)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 1.8810 (1.9193)  loss_bbox_2_unscaled: 0.1780 (0.2153)  loss_giou_2_unscaled: 0.3660 (0.3936)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 1.8936 (1.9040)  loss_bbox_3_unscaled: 0.1398 (0.2034)  loss_giou_3_unscaled: 0.2687 (0.3553)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.8266 (1.8270)  loss_bbox_4_unscaled: 0.1889 (0.2394)  loss_giou_4_unscaled: 0.3758 (0.4509)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 0.9681  data: 0.0906  max mem: 9095
# Epoch: [3] Total time: 0:00:03 (0.9888 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 20.8841 (22.2782)  loss_ce: 1.9031 (1.8963)  loss_bbox: 1.0826 (1.1032)  loss_giou: 0.7027 (0.8009)  loss_ce_0: 2.0033 (2.0546)  loss_bbox_0: 0.9056 (0.9361)  loss_giou_0: 0.8056 (0.7781)  loss_ce_1: 1.8704 (1.8943)  loss_bbox_1: 0.7434 (0.7836)  loss_giou_1: 0.6700 (0.6912)  loss_ce_2: 1.8810 (1.9193)  loss_bbox_2: 0.8901 (1.0766)  loss_giou_2: 0.7320 (0.7871)  loss_ce_3: 1.8936 (1.9040)  loss_bbox_3: 0.6992 (1.0168)  loss_giou_3: 0.5374 (0.7105)  loss_ce_4: 1.8266 (1.8270)  loss_bbox_4: 0.9447 (1.1969)  loss_giou_4: 0.7517 (0.9017)  loss_ce_unscaled: 1.9031 (1.8963)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.2165 (0.2206)  loss_giou_unscaled: 0.3513 (0.4004)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 2.0033 (2.0546)  loss_bbox_0_unscaled: 0.1811 (0.1872)  loss_giou_0_unscaled: 0.4028 (0.3890)  cardinality_error_0_unscaled: 97.0000 (97.0000)  loss_ce_1_unscaled: 1.8704 (1.8943)  loss_bbox_1_unscaled: 0.1487 (0.1567)  loss_giou_1_unscaled: 0.3350 (0.3456)  cardinality_error_1_unscaled: 97.0000 (97.0000)  loss_ce_2_unscaled: 1.8810 (1.9193)  loss_bbox_2_unscaled: 0.1780 (0.2153)  loss_giou_2_unscaled: 0.3660 (0.3936)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 1.8936 (1.9040)  loss_bbox_3_unscaled: 0.1398 (0.2034)  loss_giou_3_unscaled: 0.2687 (0.3553)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.8266 (1.8270)  loss_bbox_4_unscaled: 0.1889 (0.2394)  loss_giou_4_unscaled: 0.3758 (0.4509)  cardinality_error_4_unscaled: 97.0000 (97.0000)
# Epoch: [4]  [0/4]  eta: 0:00:05  lr: 0.000100  class_error: 100.00  loss: 19.8179 (19.8179)  loss_ce: 1.8566 (1.8566)  loss_bbox: 0.8234 (0.8234)  loss_giou: 0.5825 (0.5825)  loss_ce_0: 1.9192 (1.9192)  loss_bbox_0: 0.9125 (0.9125)  loss_giou_0: 0.5817 (0.5817)  loss_ce_1: 1.9170 (1.9170)  loss_bbox_1: 0.6438 (0.6438)  loss_giou_1: 0.5666 (0.5666)  loss_ce_2: 1.9475 (1.9475)  loss_bbox_2: 0.7505 (0.7505)  loss_giou_2: 0.6732 (0.6732)  loss_ce_3: 1.8348 (1.8348)  loss_bbox_3: 0.7854 (0.7854)  loss_giou_3: 0.7426 (0.7426)  loss_ce_4: 1.9139 (1.9139)  loss_bbox_4: 0.6962 (0.6962)  loss_giou_4: 0.6708 (0.6708)  loss_ce_unscaled: 1.8566 (1.8566)  class_error_unscaled: 100.0000 (100.0000)  loss_bbox_unscaled: 0.1647 (0.1647)  loss_giou_unscaled: 0.2912 (0.2912)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9192 (1.9192)  loss_bbox_0_unscaled: 0.1825 (0.1825)  loss_giou_0_unscaled: 0.2909 (0.2909)  cardinality_error_0_unscaled: 96.0000 (96.0000)  loss_ce_1_unscaled: 1.9170 (1.9170)  loss_bbox_1_unscaled: 0.1288 (0.1288)  loss_giou_1_unscaled: 0.2833 (0.2833)  cardinality_error_1_unscaled: 95.0000 (95.0000)  loss_ce_2_unscaled: 1.9475 (1.9475)  loss_bbox_2_unscaled: 0.1501 (0.1501)  loss_giou_2_unscaled: 0.3366 (0.3366)  cardinality_error_2_unscaled: 97.0000 (97.0000)  loss_ce_3_unscaled: 1.8348 (1.8348)  loss_bbox_3_unscaled: 0.1571 (0.1571)  loss_giou_3_unscaled: 0.3713 (0.3713)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.9139 (1.9139)  loss_bbox_4_unscaled: 0.1392 (0.1392)  loss_giou_4_unscaled: 0.3354 (0.3354)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 1.2865  data: 0.3475  max mem: 9095
# Epoch: [4]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 20.5910 (21.6606)  loss_ce: 1.8091 (1.8390)  loss_bbox: 0.8234 (1.2362)  loss_giou: 0.7661 (0.7860)  loss_ce_0: 1.9944 (1.9955)  loss_bbox_0: 0.9125 (0.9710)  loss_giou_0: 0.6878 (0.6802)  loss_ce_1: 1.9194 (1.9343)  loss_bbox_1: 0.8377 (0.9500)  loss_giou_1: 0.6688 (0.6716)  loss_ce_2: 1.9475 (1.9533)  loss_bbox_2: 0.7505 (0.8155)  loss_giou_2: 0.6732 (0.6764)  loss_ce_3: 1.8348 (1.8726)  loss_bbox_3: 0.7854 (0.9430)  loss_giou_3: 0.6849 (0.7311)  loss_ce_4: 1.8420 (1.8519)  loss_bbox_4: 0.6962 (1.0065)  loss_giou_4: 0.6708 (0.7466)  loss_ce_unscaled: 1.8091 (1.8390)  class_error_unscaled: 66.6667 (83.3333)  loss_bbox_unscaled: 0.1647 (0.2472)  loss_giou_unscaled: 0.3831 (0.3930)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9944 (1.9955)  loss_bbox_0_unscaled: 0.1825 (0.1942)  loss_giou_0_unscaled: 0.3439 (0.3401)  cardinality_error_0_unscaled: 97.0000 (96.7500)  loss_ce_1_unscaled: 1.9194 (1.9343)  loss_bbox_1_unscaled: 0.1675 (0.1900)  loss_giou_1_unscaled: 0.3344 (0.3358)  cardinality_error_1_unscaled: 95.0000 (95.0000)  loss_ce_2_unscaled: 1.9475 (1.9533)  loss_bbox_2_unscaled: 0.1501 (0.1631)  loss_giou_2_unscaled: 0.3366 (0.3382)  cardinality_error_2_unscaled: 97.0000 (96.7500)  loss_ce_3_unscaled: 1.8348 (1.8726)  loss_bbox_3_unscaled: 0.1571 (0.1886)  loss_giou_3_unscaled: 0.3425 (0.3655)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.8420 (1.8519)  loss_bbox_4_unscaled: 0.1392 (0.2013)  loss_giou_4_unscaled: 0.3354 (0.3733)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 0.9801  data: 0.0913  max mem: 9095
# Epoch: [4] Total time: 0:00:04 (1.0100 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 20.5910 (21.6606)  loss_ce: 1.8091 (1.8390)  loss_bbox: 0.8234 (1.2362)  loss_giou: 0.7661 (0.7860)  loss_ce_0: 1.9944 (1.9955)  loss_bbox_0: 0.9125 (0.9710)  loss_giou_0: 0.6878 (0.6802)  loss_ce_1: 1.9194 (1.9343)  loss_bbox_1: 0.8377 (0.9500)  loss_giou_1: 0.6688 (0.6716)  loss_ce_2: 1.9475 (1.9533)  loss_bbox_2: 0.7505 (0.8155)  loss_giou_2: 0.6732 (0.6764)  loss_ce_3: 1.8348 (1.8726)  loss_bbox_3: 0.7854 (0.9430)  loss_giou_3: 0.6849 (0.7311)  loss_ce_4: 1.8420 (1.8519)  loss_bbox_4: 0.6962 (1.0065)  loss_giou_4: 0.6708 (0.7466)  loss_ce_unscaled: 1.8091 (1.8390)  class_error_unscaled: 66.6667 (83.3333)  loss_bbox_unscaled: 0.1647 (0.2472)  loss_giou_unscaled: 0.3831 (0.3930)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9944 (1.9955)  loss_bbox_0_unscaled: 0.1825 (0.1942)  loss_giou_0_unscaled: 0.3439 (0.3401)  cardinality_error_0_unscaled: 97.0000 (96.7500)  loss_ce_1_unscaled: 1.9194 (1.9343)  loss_bbox_1_unscaled: 0.1675 (0.1900)  loss_giou_1_unscaled: 0.3344 (0.3358)  cardinality_error_1_unscaled: 95.0000 (95.0000)  loss_ce_2_unscaled: 1.9475 (1.9533)  loss_bbox_2_unscaled: 0.1501 (0.1631)  loss_giou_2_unscaled: 0.3366 (0.3382)  cardinality_error_2_unscaled: 97.0000 (96.7500)  loss_ce_3_unscaled: 1.8348 (1.8726)  loss_bbox_3_unscaled: 0.1571 (0.1886)  loss_giou_3_unscaled: 0.3425 (0.3655)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.8420 (1.8519)  loss_bbox_4_unscaled: 0.1392 (0.2013)  loss_giou_4_unscaled: 0.3354 (0.3733)  cardinality_error_4_unscaled: 97.0000 (97.0000)
# Epoch: [5]  [0/4]  eta: 0:00:05  lr: 0.000100  class_error: 66.67  loss: 24.7308 (24.7308)  loss_ce: 1.7583 (1.7583)  loss_bbox: 1.8090 (1.8090)  loss_giou: 0.9390 (0.9390)  loss_ce_0: 1.9757 (1.9757)  loss_bbox_0: 1.5344 (1.5344)  loss_giou_0: 0.8028 (0.8028)  loss_ce_1: 1.8452 (1.8452)  loss_bbox_1: 1.6005 (1.6005)  loss_giou_1: 0.9009 (0.9009)  loss_ce_2: 1.7942 (1.7942)  loss_bbox_2: 1.3773 (1.3773)  loss_giou_2: 0.8984 (0.8984)  loss_ce_3: 1.8501 (1.8501)  loss_bbox_3: 0.9317 (0.9317)  loss_giou_3: 0.7703 (0.7703)  loss_ce_4: 1.7297 (1.7297)  loss_bbox_4: 1.3814 (1.3814)  loss_giou_4: 0.8319 (0.8319)  loss_ce_unscaled: 1.7583 (1.7583)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.3618 (0.3618)  loss_giou_unscaled: 0.4695 (0.4695)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9757 (1.9757)  loss_bbox_0_unscaled: 0.3069 (0.3069)  loss_giou_0_unscaled: 0.4014 (0.4014)  cardinality_error_0_unscaled: 96.0000 (96.0000)  loss_ce_1_unscaled: 1.8452 (1.8452)  loss_bbox_1_unscaled: 0.3201 (0.3201)  loss_giou_1_unscaled: 0.4504 (0.4504)  cardinality_error_1_unscaled: 96.0000 (96.0000)  loss_ce_2_unscaled: 1.7942 (1.7942)  loss_bbox_2_unscaled: 0.2755 (0.2755)  loss_giou_2_unscaled: 0.4492 (0.4492)  cardinality_error_2_unscaled: 95.0000 (95.0000)  loss_ce_3_unscaled: 1.8501 (1.8501)  loss_bbox_3_unscaled: 0.1863 (0.1863)  loss_giou_3_unscaled: 0.3851 (0.3851)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.7297 (1.7297)  loss_bbox_4_unscaled: 0.2763 (0.2763)  loss_giou_4_unscaled: 0.4160 (0.4160)  cardinality_error_4_unscaled: 96.0000 (96.0000)  time: 1.2582  data: 0.3400  max mem: 9095
# Epoch: [5]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 21.1197 (21.7207)  loss_ce: 1.7372 (1.7767)  loss_bbox: 1.1343 (1.4583)  loss_giou: 0.8805 (0.8527)  loss_ce_0: 1.9454 (1.9789)  loss_bbox_0: 0.8874 (0.9730)  loss_giou_0: 0.6353 (0.6505)  loss_ce_1: 1.9108 (1.9036)  loss_bbox_1: 0.7830 (1.0000)  loss_giou_1: 0.7156 (0.7182)  loss_ce_2: 1.8649 (1.8854)  loss_bbox_2: 0.9875 (0.9870)  loss_giou_2: 0.7039 (0.6872)  loss_ce_3: 1.7965 (1.8326)  loss_bbox_3: 0.8148 (0.8331)  loss_giou_3: 0.7079 (0.6766)  loss_ce_4: 1.7321 (1.7358)  loss_bbox_4: 0.7873 (1.0278)  loss_giou_4: 0.7384 (0.7432)  loss_ce_unscaled: 1.7372 (1.7767)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.2269 (0.2917)  loss_giou_unscaled: 0.4403 (0.4264)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9454 (1.9789)  loss_bbox_0_unscaled: 0.1775 (0.1946)  loss_giou_0_unscaled: 0.3177 (0.3252)  cardinality_error_0_unscaled: 96.0000 (96.2500)  loss_ce_1_unscaled: 1.9108 (1.9036)  loss_bbox_1_unscaled: 0.1566 (0.2000)  loss_giou_1_unscaled: 0.3578 (0.3591)  cardinality_error_1_unscaled: 93.0000 (93.7500)  loss_ce_2_unscaled: 1.8649 (1.8854)  loss_bbox_2_unscaled: 0.1975 (0.1974)  loss_giou_2_unscaled: 0.3520 (0.3436)  cardinality_error_2_unscaled: 95.0000 (95.2500)  loss_ce_3_unscaled: 1.7965 (1.8326)  loss_bbox_3_unscaled: 0.1630 (0.1666)  loss_giou_3_unscaled: 0.3540 (0.3383)  cardinality_error_3_unscaled: 96.0000 (96.0000)  loss_ce_4_unscaled: 1.7321 (1.7358)  loss_bbox_4_unscaled: 0.1575 (0.2056)  loss_giou_4_unscaled: 0.3692 (0.3716)  cardinality_error_4_unscaled: 97.0000 (96.7500)  time: 0.9653  data: 0.0897  max mem: 9095
# Epoch: [5] Total time: 0:00:03 (0.9854 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 21.1197 (21.7207)  loss_ce: 1.7372 (1.7767)  loss_bbox: 1.1343 (1.4583)  loss_giou: 0.8805 (0.8527)  loss_ce_0: 1.9454 (1.9789)  loss_bbox_0: 0.8874 (0.9730)  loss_giou_0: 0.6353 (0.6505)  loss_ce_1: 1.9108 (1.9036)  loss_bbox_1: 0.7830 (1.0000)  loss_giou_1: 0.7156 (0.7182)  loss_ce_2: 1.8649 (1.8854)  loss_bbox_2: 0.9875 (0.9870)  loss_giou_2: 0.7039 (0.6872)  loss_ce_3: 1.7965 (1.8326)  loss_bbox_3: 0.8148 (0.8331)  loss_giou_3: 0.7079 (0.6766)  loss_ce_4: 1.7321 (1.7358)  loss_bbox_4: 0.7873 (1.0278)  loss_giou_4: 0.7384 (0.7432)  loss_ce_unscaled: 1.7372 (1.7767)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.2269 (0.2917)  loss_giou_unscaled: 0.4403 (0.4264)  cardinality_error_unscaled: 97.0000 (97.0000)  loss_ce_0_unscaled: 1.9454 (1.9789)  loss_bbox_0_unscaled: 0.1775 (0.1946)  loss_giou_0_unscaled: 0.3177 (0.3252)  cardinality_error_0_unscaled: 96.0000 (96.2500)  loss_ce_1_unscaled: 1.9108 (1.9036)  loss_bbox_1_unscaled: 0.1566 (0.2000)  loss_giou_1_unscaled: 0.3578 (0.3591)  cardinality_error_1_unscaled: 93.0000 (93.7500)  loss_ce_2_unscaled: 1.8649 (1.8854)  loss_bbox_2_unscaled: 0.1975 (0.1974)  loss_giou_2_unscaled: 0.3520 (0.3436)  cardinality_error_2_unscaled: 95.0000 (95.2500)  loss_ce_3_unscaled: 1.7965 (1.8326)  loss_bbox_3_unscaled: 0.1630 (0.1666)  loss_giou_3_unscaled: 0.3540 (0.3383)  cardinality_error_3_unscaled: 96.0000 (96.0000)  loss_ce_4_unscaled: 1.7321 (1.7358)  loss_bbox_4_unscaled: 0.1575 (0.2056)  loss_giou_4_unscaled: 0.3692 (0.3716)  cardinality_error_4_unscaled: 97.0000 (96.7500)
# Epoch: [6]  [0/4]  eta: 0:00:04  lr: 0.000100  class_error: 66.67  loss: 18.0348 (18.0348)  loss_ce: 1.7514 (1.7514)  loss_bbox: 1.0432 (1.0432)  loss_giou: 0.6530 (0.6530)  loss_ce_0: 1.9891 (1.9891)  loss_bbox_0: 0.7841 (0.7841)  loss_giou_0: 0.5718 (0.5718)  loss_ce_1: 1.8811 (1.8811)  loss_bbox_1: 0.5995 (0.5995)  loss_giou_1: 0.3708 (0.3708)  loss_ce_2: 1.8632 (1.8632)  loss_bbox_2: 0.6362 (0.6362)  loss_giou_2: 0.4983 (0.4983)  loss_ce_3: 1.7198 (1.7198)  loss_bbox_3: 0.4533 (0.4533)  loss_giou_3: 0.4076 (0.4076)  loss_ce_4: 1.7270 (1.7270)  loss_bbox_4: 0.4915 (0.4915)  loss_giou_4: 0.5940 (0.5940)  loss_ce_unscaled: 1.7514 (1.7514)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.2086 (0.2086)  loss_giou_unscaled: 0.3265 (0.3265)  cardinality_error_unscaled: 96.0000 (96.0000)  loss_ce_0_unscaled: 1.9891 (1.9891)  loss_bbox_0_unscaled: 0.1568 (0.1568)  loss_giou_0_unscaled: 0.2859 (0.2859)  cardinality_error_0_unscaled: 96.0000 (96.0000)  loss_ce_1_unscaled: 1.8811 (1.8811)  loss_bbox_1_unscaled: 0.1199 (0.1199)  loss_giou_1_unscaled: 0.1854 (0.1854)  cardinality_error_1_unscaled: 94.0000 (94.0000)  loss_ce_2_unscaled: 1.8632 (1.8632)  loss_bbox_2_unscaled: 0.1272 (0.1272)  loss_giou_2_unscaled: 0.2491 (0.2491)  cardinality_error_2_unscaled: 96.0000 (96.0000)  loss_ce_3_unscaled: 1.7198 (1.7198)  loss_bbox_3_unscaled: 0.0907 (0.0907)  loss_giou_3_unscaled: 0.2038 (0.2038)  cardinality_error_3_unscaled: 97.0000 (97.0000)  loss_ce_4_unscaled: 1.7270 (1.7270)  loss_bbox_4_unscaled: 0.0983 (0.0983)  loss_giou_4_unscaled: 0.2970 (0.2970)  cardinality_error_4_unscaled: 97.0000 (97.0000)  time: 1.2359  data: 0.3078  max mem: 9095
# Epoch: [6]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 18.0348 (18.6288)  loss_ce: 1.7514 (1.7652)  loss_bbox: 0.6867 (0.7827)  loss_giou: 0.5819 (0.6125)  loss_ce_0: 1.9010 (1.9167)  loss_bbox_0: 0.7792 (0.7993)  loss_giou_0: 0.5883 (0.6432)  loss_ce_1: 1.8811 (1.8696)  loss_bbox_1: 0.5995 (0.7524)  loss_giou_1: 0.5446 (0.5549)  loss_ce_2: 1.8632 (1.8835)  loss_bbox_2: 0.6230 (0.6303)  loss_giou_2: 0.4983 (0.5429)  loss_ce_3: 1.7291 (1.7494)  loss_bbox_3: 0.6147 (0.6867)  loss_giou_3: 0.4913 (0.5655)  loss_ce_4: 1.6955 (1.7041)  loss_bbox_4: 0.5360 (0.5794)  loss_giou_4: 0.5940 (0.5903)  loss_ce_unscaled: 1.7514 (1.7652)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.1373 (0.1565)  loss_giou_unscaled: 0.2910 (0.3063)  cardinality_error_unscaled: 96.0000 (96.5000)  loss_ce_0_unscaled: 1.9010 (1.9167)  loss_bbox_0_unscaled: 0.1558 (0.1599)  loss_giou_0_unscaled: 0.2942 (0.3216)  cardinality_error_0_unscaled: 96.0000 (96.2500)  loss_ce_1_unscaled: 1.8811 (1.8696)  loss_bbox_1_unscaled: 0.1199 (0.1505)  loss_giou_1_unscaled: 0.2723 (0.2775)  cardinality_error_1_unscaled: 86.0000 (87.5000)  loss_ce_2_unscaled: 1.8632 (1.8835)  loss_bbox_2_unscaled: 0.1246 (0.1261)  loss_giou_2_unscaled: 0.2491 (0.2715)  cardinality_error_2_unscaled: 91.0000 (92.2500)  loss_ce_3_unscaled: 1.7291 (1.7494)  loss_bbox_3_unscaled: 0.1229 (0.1373)  loss_giou_3_unscaled: 0.2456 (0.2827)  cardinality_error_3_unscaled: 92.0000 (93.7500)  loss_ce_4_unscaled: 1.6955 (1.7041)  loss_bbox_4_unscaled: 0.1072 (0.1159)  loss_giou_4_unscaled: 0.2970 (0.2952)  cardinality_error_4_unscaled: 96.0000 (96.0000)  time: 0.9649  data: 0.0810  max mem: 9095
# Epoch: [6] Total time: 0:00:03 (0.9828 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 18.0348 (18.6288)  loss_ce: 1.7514 (1.7652)  loss_bbox: 0.6867 (0.7827)  loss_giou: 0.5819 (0.6125)  loss_ce_0: 1.9010 (1.9167)  loss_bbox_0: 0.7792 (0.7993)  loss_giou_0: 0.5883 (0.6432)  loss_ce_1: 1.8811 (1.8696)  loss_bbox_1: 0.5995 (0.7524)  loss_giou_1: 0.5446 (0.5549)  loss_ce_2: 1.8632 (1.8835)  loss_bbox_2: 0.6230 (0.6303)  loss_giou_2: 0.4983 (0.5429)  loss_ce_3: 1.7291 (1.7494)  loss_bbox_3: 0.6147 (0.6867)  loss_giou_3: 0.4913 (0.5655)  loss_ce_4: 1.6955 (1.7041)  loss_bbox_4: 0.5360 (0.5794)  loss_giou_4: 0.5940 (0.5903)  loss_ce_unscaled: 1.7514 (1.7652)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.1373 (0.1565)  loss_giou_unscaled: 0.2910 (0.3063)  cardinality_error_unscaled: 96.0000 (96.5000)  loss_ce_0_unscaled: 1.9010 (1.9167)  loss_bbox_0_unscaled: 0.1558 (0.1599)  loss_giou_0_unscaled: 0.2942 (0.3216)  cardinality_error_0_unscaled: 96.0000 (96.2500)  loss_ce_1_unscaled: 1.8811 (1.8696)  loss_bbox_1_unscaled: 0.1199 (0.1505)  loss_giou_1_unscaled: 0.2723 (0.2775)  cardinality_error_1_unscaled: 86.0000 (87.5000)  loss_ce_2_unscaled: 1.8632 (1.8835)  loss_bbox_2_unscaled: 0.1246 (0.1261)  loss_giou_2_unscaled: 0.2491 (0.2715)  cardinality_error_2_unscaled: 91.0000 (92.2500)  loss_ce_3_unscaled: 1.7291 (1.7494)  loss_bbox_3_unscaled: 0.1229 (0.1373)  loss_giou_3_unscaled: 0.2456 (0.2827)  cardinality_error_3_unscaled: 92.0000 (93.7500)  loss_ce_4_unscaled: 1.6955 (1.7041)  loss_bbox_4_unscaled: 0.1072 (0.1159)  loss_giou_4_unscaled: 0.2970 (0.2952)  cardinality_error_4_unscaled: 96.0000 (96.0000)
# Epoch: [7]  [0/4]  eta: 0:00:05  lr: 0.000100  class_error: 66.67  loss: 21.1240 (21.1240)  loss_ce: 1.7148 (1.7148)  loss_bbox: 1.0939 (1.0939)  loss_giou: 0.9245 (0.9245)  loss_ce_0: 1.8298 (1.8298)  loss_bbox_0: 1.0076 (1.0076)  loss_giou_0: 0.7792 (0.7792)  loss_ce_1: 1.9456 (1.9456)  loss_bbox_1: 1.1844 (1.1844)  loss_giou_1: 0.7340 (0.7340)  loss_ce_2: 1.6927 (1.6927)  loss_bbox_2: 0.8989 (0.8989)  loss_giou_2: 0.5876 (0.5876)  loss_ce_3: 1.7068 (1.7068)  loss_bbox_3: 0.7378 (0.7378)  loss_giou_3: 0.5397 (0.5397)  loss_ce_4: 1.7072 (1.7072)  loss_bbox_4: 1.1569 (1.1569)  loss_giou_4: 0.8825 (0.8825)  loss_ce_unscaled: 1.7148 (1.7148)  class_error_unscaled: 66.6667 (66.6667)  loss_bbox_unscaled: 0.2188 (0.2188)  loss_giou_unscaled: 0.4623 (0.4623)  cardinality_error_unscaled: 96.0000 (96.0000)  loss_ce_0_unscaled: 1.8298 (1.8298)  loss_bbox_0_unscaled: 0.2015 (0.2015)  loss_giou_0_unscaled: 0.3896 (0.3896)  cardinality_error_0_unscaled: 93.0000 (93.0000)  loss_ce_1_unscaled: 1.9456 (1.9456)  loss_bbox_1_unscaled: 0.2369 (0.2369)  loss_giou_1_unscaled: 0.3670 (0.3670)  cardinality_error_1_unscaled: 84.0000 (84.0000)  loss_ce_2_unscaled: 1.6927 (1.6927)  loss_bbox_2_unscaled: 0.1798 (0.1798)  loss_giou_2_unscaled: 0.2938 (0.2938)  cardinality_error_2_unscaled: 90.0000 (90.0000)  loss_ce_3_unscaled: 1.7068 (1.7068)  loss_bbox_3_unscaled: 0.1476 (0.1476)  loss_giou_3_unscaled: 0.2699 (0.2699)  cardinality_error_3_unscaled: 89.0000 (89.0000)  loss_ce_4_unscaled: 1.7072 (1.7072)  loss_bbox_4_unscaled: 0.2314 (0.2314)  loss_giou_4_unscaled: 0.4413 (0.4413)  cardinality_error_4_unscaled: 96.0000 (96.0000)  time: 1.4229  data: 0.4552  max mem: 9095
# Epoch: [7]  [3/4]  eta: 0:00:01  lr: 0.000100  class_error: 66.67  loss: 21.6106 (22.0293)  loss_ce: 1.6345 (1.6609)  loss_bbox: 1.1251 (1.1534)  loss_giou: 0.8407 (0.8760)  loss_ce_0: 1.8298 (1.8812)  loss_bbox_0: 1.0513 (1.2294)  loss_giou_0: 0.7792 (0.7901)  loss_ce_1: 1.7429 (1.8045)  loss_bbox_1: 1.1844 (1.2701)  loss_giou_1: 0.7340 (0.7576)  loss_ce_2: 1.6927 (1.6848)  loss_bbox_2: 0.9979 (1.0312)  loss_giou_2: 0.7346 (0.7262)  loss_ce_3: 1.6668 (1.6606)  loss_bbox_3: 0.9907 (0.9977)  loss_giou_3: 0.7018 (0.7353)  loss_ce_4: 1.6364 (1.6534)  loss_bbox_4: 1.1287 (1.1677)  loss_giou_4: 0.8825 (0.9491)  loss_ce_unscaled: 1.6345 (1.6609)  class_error_unscaled: 66.6667 (58.3333)  loss_bbox_unscaled: 0.2250 (0.2307)  loss_giou_unscaled: 0.4204 (0.4380)  cardinality_error_unscaled: 94.0000 (92.5000)  loss_ce_0_unscaled: 1.8298 (1.8812)  loss_bbox_0_unscaled: 0.2103 (0.2459)  loss_giou_0_unscaled: 0.3896 (0.3951)  cardinality_error_0_unscaled: 90.0000 (90.5000)  loss_ce_1_unscaled: 1.7429 (1.8045)  loss_bbox_1_unscaled: 0.2369 (0.2540)  loss_giou_1_unscaled: 0.3670 (0.3788)  cardinality_error_1_unscaled: 69.0000 (72.5000)  loss_ce_2_unscaled: 1.6927 (1.6848)  loss_bbox_2_unscaled: 0.1996 (0.2062)  loss_giou_2_unscaled: 0.3673 (0.3631)  cardinality_error_2_unscaled: 82.0000 (81.5000)  loss_ce_3_unscaled: 1.6668 (1.6606)  loss_bbox_3_unscaled: 0.1981 (0.1995)  loss_giou_3_unscaled: 0.3509 (0.3677)  cardinality_error_3_unscaled: 89.0000 (89.7500)  loss_ce_4_unscaled: 1.6364 (1.6534)  loss_bbox_4_unscaled: 0.2257 (0.2335)  loss_giou_4_unscaled: 0.4413 (0.4746)  cardinality_error_4_unscaled: 95.0000 (94.0000)  time: 1.0066  data: 0.1191  max mem: 9095
# Epoch: [7] Total time: 0:00:04 (1.0263 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 21.6106 (22.0293)  loss_ce: 1.6345 (1.6609)  loss_bbox: 1.1251 (1.1534)  loss_giou: 0.8407 (0.8760)  loss_ce_0: 1.8298 (1.8812)  loss_bbox_0: 1.0513 (1.2294)  loss_giou_0: 0.7792 (0.7901)  loss_ce_1: 1.7429 (1.8045)  loss_bbox_1: 1.1844 (1.2701)  loss_giou_1: 0.7340 (0.7576)  loss_ce_2: 1.6927 (1.6848)  loss_bbox_2: 0.9979 (1.0312)  loss_giou_2: 0.7346 (0.7262)  loss_ce_3: 1.6668 (1.6606)  loss_bbox_3: 0.9907 (0.9977)  loss_giou_3: 0.7018 (0.7353)  loss_ce_4: 1.6364 (1.6534)  loss_bbox_4: 1.1287 (1.1677)  loss_giou_4: 0.8825 (0.9491)  loss_ce_unscaled: 1.6345 (1.6609)  class_error_unscaled: 66.6667 (58.3333)  loss_bbox_unscaled: 0.2250 (0.2307)  loss_giou_unscaled: 0.4204 (0.4380)  cardinality_error_unscaled: 94.0000 (92.5000)  loss_ce_0_unscaled: 1.8298 (1.8812)  loss_bbox_0_unscaled: 0.2103 (0.2459)  loss_giou_0_unscaled: 0.3896 (0.3951)  cardinality_error_0_unscaled: 90.0000 (90.5000)  loss_ce_1_unscaled: 1.7429 (1.8045)  loss_bbox_1_unscaled: 0.2369 (0.2540)  loss_giou_1_unscaled: 0.3670 (0.3788)  cardinality_error_1_unscaled: 69.0000 (72.5000)  loss_ce_2_unscaled: 1.6927 (1.6848)  loss_bbox_2_unscaled: 0.1996 (0.2062)  loss_giou_2_unscaled: 0.3673 (0.3631)  cardinality_error_2_unscaled: 82.0000 (81.5000)  loss_ce_3_unscaled: 1.6668 (1.6606)  loss_bbox_3_unscaled: 0.1981 (0.1995)  loss_giou_3_unscaled: 0.3509 (0.3677)  cardinality_error_3_unscaled: 89.0000 (89.7500)  loss_ce_4_unscaled: 1.6364 (1.6534)  loss_bbox_4_unscaled: 0.2257 (0.2335)  loss_giou_4_unscaled: 0.4413 (0.4746)  cardinality_error_4_unscaled: 95.0000 (94.0000)
# Epoch: [8]  [0/4]  eta: 0:00:04  lr: 0.000100  class_error: 33.33  loss: 19.1779 (19.1779)  loss_ce: 1.5797 (1.5797)  loss_bbox: 0.7939 (0.7939)  loss_giou: 0.6111 (0.6111)  loss_ce_0: 1.7546 (1.7546)  loss_bbox_0: 1.0158 (1.0158)  loss_giou_0: 0.6661 (0.6661)  loss_ce_1: 1.7561 (1.7561)  loss_bbox_1: 0.9507 (0.9507)  loss_giou_1: 0.5785 (0.5785)  loss_ce_2: 1.7272 (1.7272)  loss_bbox_2: 0.7937 (0.7937)  loss_giou_2: 0.6103 (0.6103)  loss_ce_3: 1.6895 (1.6895)  loss_bbox_3: 0.8746 (0.8746)  loss_giou_3: 0.6829 (0.6829)  loss_ce_4: 1.6599 (1.6599)  loss_bbox_4: 0.8026 (0.8026)  loss_giou_4: 0.6305 (0.6305)  loss_ce_unscaled: 1.5797 (1.5797)  class_error_unscaled: 33.3333 (33.3333)  loss_bbox_unscaled: 0.1588 (0.1588)  loss_giou_unscaled: 0.3055 (0.3055)  cardinality_error_unscaled: 74.0000 (74.0000)  loss_ce_0_unscaled: 1.7546 (1.7546)  loss_bbox_0_unscaled: 0.2032 (0.2032)  loss_giou_0_unscaled: 0.3331 (0.3331)  cardinality_error_0_unscaled: 85.0000 (85.0000)  loss_ce_1_unscaled: 1.7561 (1.7561)  loss_bbox_1_unscaled: 0.1901 (0.1901)  loss_giou_1_unscaled: 0.2893 (0.2893)  cardinality_error_1_unscaled: 63.0000 (63.0000)  loss_ce_2_unscaled: 1.7272 (1.7272)  loss_bbox_2_unscaled: 0.1587 (0.1587)  loss_giou_2_unscaled: 0.3052 (0.3052)  cardinality_error_2_unscaled: 63.0000 (63.0000)  loss_ce_3_unscaled: 1.6895 (1.6895)  loss_bbox_3_unscaled: 0.1749 (0.1749)  loss_giou_3_unscaled: 0.3415 (0.3415)  cardinality_error_3_unscaled: 82.0000 (82.0000)  loss_ce_4_unscaled: 1.6599 (1.6599)  loss_bbox_4_unscaled: 0.1605 (0.1605)  loss_giou_4_unscaled: 0.3153 (0.3153)  cardinality_error_4_unscaled: 85.0000 (85.0000)  time: 1.2316  data: 0.2923  max mem: 9095
# Epoch: [8]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 66.67  loss: 16.9437 (18.8487)  loss_ce: 1.5036 (1.5602)  loss_bbox: 0.5615 (0.7135)  loss_giou: 0.6111 (0.6275)  loss_ce_0: 1.6991 (1.7313)  loss_bbox_0: 0.8729 (0.9723)  loss_giou_0: 0.6452 (0.7011)  loss_ce_1: 1.6504 (1.6729)  loss_bbox_1: 0.8095 (0.9304)  loss_giou_1: 0.5785 (0.6584)  loss_ce_2: 1.6209 (1.6409)  loss_bbox_2: 0.7113 (0.7897)  loss_giou_2: 0.5730 (0.6267)  loss_ce_3: 1.6030 (1.6228)  loss_bbox_3: 0.7652 (0.8455)  loss_giou_3: 0.5660 (0.6604)  loss_ce_4: 1.5325 (1.5479)  loss_bbox_4: 0.6173 (0.8143)  loss_giou_4: 0.6305 (0.7329)  loss_ce_unscaled: 1.5036 (1.5602)  class_error_unscaled: 33.3333 (50.0000)  loss_bbox_unscaled: 0.1123 (0.1427)  loss_giou_unscaled: 0.3055 (0.3137)  cardinality_error_unscaled: 71.0000 (71.0000)  loss_ce_0_unscaled: 1.6991 (1.7313)  loss_bbox_0_unscaled: 0.1746 (0.1945)  loss_giou_0_unscaled: 0.3226 (0.3506)  cardinality_error_0_unscaled: 83.0000 (84.7500)  loss_ce_1_unscaled: 1.6504 (1.6729)  loss_bbox_1_unscaled: 0.1619 (0.1861)  loss_giou_1_unscaled: 0.2893 (0.3292)  cardinality_error_1_unscaled: 60.0000 (60.5000)  loss_ce_2_unscaled: 1.6209 (1.6409)  loss_bbox_2_unscaled: 0.1423 (0.1579)  loss_giou_2_unscaled: 0.2865 (0.3134)  cardinality_error_2_unscaled: 63.0000 (61.7500)  loss_ce_3_unscaled: 1.6030 (1.6228)  loss_bbox_3_unscaled: 0.1530 (0.1691)  loss_giou_3_unscaled: 0.2830 (0.3302)  cardinality_error_3_unscaled: 82.0000 (83.0000)  loss_ce_4_unscaled: 1.5325 (1.5479)  loss_bbox_4_unscaled: 0.1235 (0.1629)  loss_giou_4_unscaled: 0.3153 (0.3665)  cardinality_error_4_unscaled: 85.0000 (85.5000)  time: 0.9628  data: 0.0789  max mem: 9095
# Epoch: [8] Total time: 0:00:03 (0.9808 s / it)
# Averaged stats: lr: 0.000100  class_error: 66.67  loss: 16.9437 (18.8487)  loss_ce: 1.5036 (1.5602)  loss_bbox: 0.5615 (0.7135)  loss_giou: 0.6111 (0.6275)  loss_ce_0: 1.6991 (1.7313)  loss_bbox_0: 0.8729 (0.9723)  loss_giou_0: 0.6452 (0.7011)  loss_ce_1: 1.6504 (1.6729)  loss_bbox_1: 0.8095 (0.9304)  loss_giou_1: 0.5785 (0.6584)  loss_ce_2: 1.6209 (1.6409)  loss_bbox_2: 0.7113 (0.7897)  loss_giou_2: 0.5730 (0.6267)  loss_ce_3: 1.6030 (1.6228)  loss_bbox_3: 0.7652 (0.8455)  loss_giou_3: 0.5660 (0.6604)  loss_ce_4: 1.5325 (1.5479)  loss_bbox_4: 0.6173 (0.8143)  loss_giou_4: 0.6305 (0.7329)  loss_ce_unscaled: 1.5036 (1.5602)  class_error_unscaled: 33.3333 (50.0000)  loss_bbox_unscaled: 0.1123 (0.1427)  loss_giou_unscaled: 0.3055 (0.3137)  cardinality_error_unscaled: 71.0000 (71.0000)  loss_ce_0_unscaled: 1.6991 (1.7313)  loss_bbox_0_unscaled: 0.1746 (0.1945)  loss_giou_0_unscaled: 0.3226 (0.3506)  cardinality_error_0_unscaled: 83.0000 (84.7500)  loss_ce_1_unscaled: 1.6504 (1.6729)  loss_bbox_1_unscaled: 0.1619 (0.1861)  loss_giou_1_unscaled: 0.2893 (0.3292)  cardinality_error_1_unscaled: 60.0000 (60.5000)  loss_ce_2_unscaled: 1.6209 (1.6409)  loss_bbox_2_unscaled: 0.1423 (0.1579)  loss_giou_2_unscaled: 0.2865 (0.3134)  cardinality_error_2_unscaled: 63.0000 (61.7500)  loss_ce_3_unscaled: 1.6030 (1.6228)  loss_bbox_3_unscaled: 0.1530 (0.1691)  loss_giou_3_unscaled: 0.2830 (0.3302)  cardinality_error_3_unscaled: 82.0000 (83.0000)  loss_ce_4_unscaled: 1.5325 (1.5479)  loss_bbox_4_unscaled: 0.1235 (0.1629)  loss_giou_4_unscaled: 0.3153 (0.3665)  cardinality_error_4_unscaled: 85.0000 (85.5000)
# ...
# Epoch: [40]  [3/4]  eta: 0:00:01  lr: 0.000100  class_error: 0.00  loss: 5.0965 (5.3740)  loss_ce: 0.4244 (0.4269)  loss_bbox: 0.1909 (0.2029)  loss_giou: 0.1919 (0.1876)  loss_ce_0: 0.5344 (0.5500)  loss_bbox_0: 0.2440 (0.2589)  loss_giou_0: 0.2029 (0.2351)  loss_ce_1: 0.4895 (0.5142)  loss_bbox_1: 0.1629 (0.2228)  loss_giou_1: 0.1885 (0.2081)  loss_ce_2: 0.4768 (0.4948)  loss_bbox_2: 0.1555 (0.1934)  loss_giou_2: 0.1600 (0.1698)  loss_ce_3: 0.4699 (0.4826)  loss_bbox_3: 0.1270 (0.1950)  loss_giou_3: 0.1701 (0.1824)  loss_ce_4: 0.4325 (0.4464)  loss_bbox_4: 0.1441 (0.1983)  loss_giou_4: 0.2013 (0.2047)  loss_ce_unscaled: 0.4244 (0.4269)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0382 (0.0406)  loss_giou_unscaled: 0.0960 (0.0938)  cardinality_error_unscaled: 63.0000 (63.2500)  loss_ce_0_unscaled: 0.5344 (0.5500)  loss_bbox_0_unscaled: 0.0488 (0.0518)  loss_giou_0_unscaled: 0.1015 (0.1175)  cardinality_error_0_unscaled: 63.0000 (62.7500)  loss_ce_1_unscaled: 0.4895 (0.5142)  loss_bbox_1_unscaled: 0.0326 (0.0446)  loss_giou_1_unscaled: 0.0943 (0.1041)  cardinality_error_1_unscaled: 61.0000 (63.5000)  loss_ce_2_unscaled: 0.4768 (0.4948)  loss_bbox_2_unscaled: 0.0311 (0.0387)  loss_giou_2_unscaled: 0.0800 (0.0849)  cardinality_error_2_unscaled: 64.0000 (65.2500)  loss_ce_3_unscaled: 0.4699 (0.4826)  loss_bbox_3_unscaled: 0.0254 (0.0390)  loss_giou_3_unscaled: 0.0850 (0.0912)  cardinality_error_3_unscaled: 67.0000 (66.7500)  loss_ce_4_unscaled: 0.4325 (0.4464)  loss_bbox_4_unscaled: 0.0288 (0.0397)  loss_giou_4_unscaled: 0.1006 (0.1023)  cardinality_error_4_unscaled: 65.0000 (66.0000)  time: 1.0141  data: 0.0916  max mem: 9095
# Epoch: [40] Total time: 0:00:04 (1.0336 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 5.0965 (5.3740)  loss_ce: 0.4244 (0.4269)  loss_bbox: 0.1909 (0.2029)  loss_giou: 0.1919 (0.1876)  loss_ce_0: 0.5344 (0.5500)  loss_bbox_0: 0.2440 (0.2589)  loss_giou_0: 0.2029 (0.2351)  loss_ce_1: 0.4895 (0.5142)  loss_bbox_1: 0.1629 (0.2228)  loss_giou_1: 0.1885 (0.2081)  loss_ce_2: 0.4768 (0.4948)  loss_bbox_2: 0.1555 (0.1934)  loss_giou_2: 0.1600 (0.1698)  loss_ce_3: 0.4699 (0.4826)  loss_bbox_3: 0.1270 (0.1950)  loss_giou_3: 0.1701 (0.1824)  loss_ce_4: 0.4325 (0.4464)  loss_bbox_4: 0.1441 (0.1983)  loss_giou_4: 0.2013 (0.2047)  loss_ce_unscaled: 0.4244 (0.4269)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0382 (0.0406)  loss_giou_unscaled: 0.0960 (0.0938)  cardinality_error_unscaled: 63.0000 (63.2500)  loss_ce_0_unscaled: 0.5344 (0.5500)  loss_bbox_0_unscaled: 0.0488 (0.0518)  loss_giou_0_unscaled: 0.1015 (0.1175)  cardinality_error_0_unscaled: 63.0000 (62.7500)  loss_ce_1_unscaled: 0.4895 (0.5142)  loss_bbox_1_unscaled: 0.0326 (0.0446)  loss_giou_1_unscaled: 0.0943 (0.1041)  cardinality_error_1_unscaled: 61.0000 (63.5000)  loss_ce_2_unscaled: 0.4768 (0.4948)  loss_bbox_2_unscaled: 0.0311 (0.0387)  loss_giou_2_unscaled: 0.0800 (0.0849)  cardinality_error_2_unscaled: 64.0000 (65.2500)  loss_ce_3_unscaled: 0.4699 (0.4826)  loss_bbox_3_unscaled: 0.0254 (0.0390)  loss_giou_3_unscaled: 0.0850 (0.0912)  cardinality_error_3_unscaled: 67.0000 (66.7500)  loss_ce_4_unscaled: 0.4325 (0.4464)  loss_bbox_4_unscaled: 0.0288 (0.0397)  loss_giou_4_unscaled: 0.1006 (0.1023)  cardinality_error_4_unscaled: 65.0000 (66.0000)
# Epoch: [41]  [0/4]  eta: 0:00:05  lr: 0.000100  class_error: 0.00  loss: 4.3509 (4.3509)  loss_ce: 0.4051 (0.4051)  loss_bbox: 0.1045 (0.1045)  loss_giou: 0.1355 (0.1355)  loss_ce_0: 0.5350 (0.5350)  loss_bbox_0: 0.1489 (0.1489)  loss_giou_0: 0.1545 (0.1545)  loss_ce_1: 0.4511 (0.4511)  loss_bbox_1: 0.1869 (0.1869)  loss_giou_1: 0.1974 (0.1974)  loss_ce_2: 0.4392 (0.4392)  loss_bbox_2: 0.1178 (0.1178)  loss_giou_2: 0.1309 (0.1309)  loss_ce_3: 0.4249 (0.4249)  loss_bbox_3: 0.1356 (0.1356)  loss_giou_3: 0.1468 (0.1468)  loss_ce_4: 0.4134 (0.4134)  loss_bbox_4: 0.1150 (0.1150)  loss_giou_4: 0.1085 (0.1085)  loss_ce_unscaled: 0.4051 (0.4051)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0209 (0.0209)  loss_giou_unscaled: 0.0677 (0.0677)  cardinality_error_unscaled: 60.0000 (60.0000)  loss_ce_0_unscaled: 0.5350 (0.5350)  loss_bbox_0_unscaled: 0.0298 (0.0298)  loss_giou_0_unscaled: 0.0772 (0.0772)  cardinality_error_0_unscaled: 64.0000 (64.0000)  loss_ce_1_unscaled: 0.4511 (0.4511)  loss_bbox_1_unscaled: 0.0374 (0.0374)  loss_giou_1_unscaled: 0.0987 (0.0987)  cardinality_error_1_unscaled: 61.0000 (61.0000)  loss_ce_2_unscaled: 0.4392 (0.4392)  loss_bbox_2_unscaled: 0.0236 (0.0236)  loss_giou_2_unscaled: 0.0655 (0.0655)  cardinality_error_2_unscaled: 66.0000 (66.0000)  loss_ce_3_unscaled: 0.4249 (0.4249)  loss_bbox_3_unscaled: 0.0271 (0.0271)  loss_giou_3_unscaled: 0.0734 (0.0734)  cardinality_error_3_unscaled: 65.0000 (65.0000)  loss_ce_4_unscaled: 0.4134 (0.4134)  loss_bbox_4_unscaled: 0.0230 (0.0230)  loss_giou_4_unscaled: 0.0543 (0.0543)  cardinality_error_4_unscaled: 62.0000 (62.0000)  time: 1.2709  data: 0.3045  max mem: 9095
# Epoch: [41]  [3/4]  eta: 0:00:00  lr: 0.000100  class_error: 0.00  loss: 4.9202 (5.1508)  loss_ce: 0.4399 (0.4425)  loss_bbox: 0.1300 (0.1466)  loss_giou: 0.1418 (0.1723)  loss_ce_0: 0.5350 (0.5482)  loss_bbox_0: 0.1859 (0.1978)  loss_giou_0: 0.1581 (0.2126)  loss_ce_1: 0.4934 (0.5106)  loss_bbox_1: 0.1983 (0.2195)  loss_giou_1: 0.1974 (0.2128)  loss_ce_2: 0.4622 (0.4736)  loss_bbox_2: 0.1763 (0.1888)  loss_giou_2: 0.1828 (0.1966)  loss_ce_3: 0.4640 (0.4645)  loss_bbox_3: 0.1599 (0.1724)  loss_giou_3: 0.1468 (0.1812)  loss_ce_4: 0.4275 (0.4448)  loss_bbox_4: 0.1891 (0.1917)  loss_giou_4: 0.1441 (0.1742)  loss_ce_unscaled: 0.4399 (0.4425)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0260 (0.0293)  loss_giou_unscaled: 0.0709 (0.0861)  cardinality_error_unscaled: 60.0000 (60.5000)  loss_ce_0_unscaled: 0.5350 (0.5482)  loss_bbox_0_unscaled: 0.0372 (0.0396)  loss_giou_0_unscaled: 0.0790 (0.1063)  cardinality_error_0_unscaled: 62.0000 (62.2500)  loss_ce_1_unscaled: 0.4934 (0.5106)  loss_bbox_1_unscaled: 0.0397 (0.0439)  loss_giou_1_unscaled: 0.0987 (0.1064)  cardinality_error_1_unscaled: 61.0000 (61.2500)  loss_ce_2_unscaled: 0.4622 (0.4736)  loss_bbox_2_unscaled: 0.0353 (0.0378)  loss_giou_2_unscaled: 0.0914 (0.0983)  cardinality_error_2_unscaled: 66.0000 (64.7500)  loss_ce_3_unscaled: 0.4640 (0.4645)  loss_bbox_3_unscaled: 0.0320 (0.0345)  loss_giou_3_unscaled: 0.0734 (0.0906)  cardinality_error_3_unscaled: 65.0000 (64.7500)  loss_ce_4_unscaled: 0.4275 (0.4448)  loss_bbox_4_unscaled: 0.0378 (0.0383)  loss_giou_4_unscaled: 0.0721 (0.0871)  cardinality_error_4_unscaled: 62.0000 (62.5000)  time: 0.9887  data: 0.0816  max mem: 9095
# Epoch: [41] Total time: 0:00:04 (1.0196 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 4.9202 (5.1508)  loss_ce: 0.4399 (0.4425)  loss_bbox: 0.1300 (0.1466)  loss_giou: 0.1418 (0.1723)  loss_ce_0: 0.5350 (0.5482)  loss_bbox_0: 0.1859 (0.1978)  loss_giou_0: 0.1581 (0.2126)  loss_ce_1: 0.4934 (0.5106)  loss_bbox_1: 0.1983 (0.2195)  loss_giou_1: 0.1974 (0.2128)  loss_ce_2: 0.4622 (0.4736)  loss_bbox_2: 0.1763 (0.1888)  loss_giou_2: 0.1828 (0.1966)  loss_ce_3: 0.4640 (0.4645)  loss_bbox_3: 0.1599 (0.1724)  loss_giou_3: 0.1468 (0.1812)  loss_ce_4: 0.4275 (0.4448)  loss_bbox_4: 0.1891 (0.1917)  loss_giou_4: 0.1441 (0.1742)  loss_ce_unscaled: 0.4399 (0.4425)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0260 (0.0293)  loss_giou_unscaled: 0.0709 (0.0861)  cardinality_error_unscaled: 60.0000 (60.5000)  loss_ce_0_unscaled: 0.5350 (0.5482)  loss_bbox_0_unscaled: 0.0372 (0.0396)  loss_giou_0_unscaled: 0.0790 (0.1063)  cardinality_error_0_unscaled: 62.0000 (62.2500)  loss_ce_1_unscaled: 0.4934 (0.5106)  loss_bbox_1_unscaled: 0.0397 (0.0439)  loss_giou_1_unscaled: 0.0987 (0.1064)  cardinality_error_1_unscaled: 61.0000 (61.2500)  loss_ce_2_unscaled: 0.4622 (0.4736)  loss_bbox_2_unscaled: 0.0353 (0.0378)  loss_giou_2_unscaled: 0.0914 (0.0983)  cardinality_error_2_unscaled: 66.0000 (64.7500)  loss_ce_3_unscaled: 0.4640 (0.4645)  loss_bbox_3_unscaled: 0.0320 (0.0345)  loss_giou_3_unscaled: 0.0734 (0.0906)  cardinality_error_3_unscaled: 65.0000 (64.7500)  loss_ce_4_unscaled: 0.4275 (0.4448)  loss_bbox_4_unscaled: 0.0378 (0.0383)  loss_giou_4_unscaled: 0.0721 (0.0871)  cardinality_error_4_unscaled: 62.0000 (62.5000)
# Epoch: [42]  [0/4]  eta: 0:00:05  lr: 0.000100  class_error: 0.00  loss: 6.2587 (6.2587)  loss_ce: 0.4872 (0.4872)  loss_bbox: 0.1800 (0.1800)  loss_giou: 0.1944 (0.1944)  loss_ce_0: 0.5768 (0.5768)  loss_bbox_0: 0.3132 (0.3132)  loss_giou_0: 0.3459 (0.3459)  loss_ce_1: 0.6063 (0.6063)  loss_bbox_1: 0.2278 (0.2278)  loss_giou_1: 0.2008 (0.2008)  loss_ce_2: 0.5170 (0.5170)  loss_bbox_2: 0.3519 (0.3519)  loss_giou_2: 0.2418 (0.2418)  loss_ce_3: 0.4973 (0.4973)  loss_bbox_3: 0.3108 (0.3108)  loss_giou_3: 0.2368 (0.2368)  loss_ce_4: 0.5131 (0.5131)  loss_bbox_4: 0.2457 (0.2457)  loss_giou_4: 0.2121 (0.2121)  loss_ce_unscaled: 0.4872 (0.4872)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0360 (0.0360)  loss_giou_unscaled: 0.0972 (0.0972)  cardinality_error_unscaled: 52.0000 (52.0000)  loss_ce_0_unscaled: 0.5768 (0.5768)  loss_bbox_0_unscaled: 0.0626 (0.0626)  loss_giou_0_unscaled: 0.1729 (0.1729)  cardinality_error_0_unscaled: 60.0000 (60.0000)  loss_ce_1_unscaled: 0.6063 (0.6063)  loss_bbox_1_unscaled: 0.0456 (0.0456)  loss_giou_1_unscaled: 0.1004 (0.1004)  cardinality_error_1_unscaled: 55.0000 (55.0000)  loss_ce_2_unscaled: 0.5170 (0.5170)  loss_bbox_2_unscaled: 0.0704 (0.0704)  loss_giou_2_unscaled: 0.1209 (0.1209)  cardinality_error_2_unscaled: 54.0000 (54.0000)  loss_ce_3_unscaled: 0.4973 (0.4973)  loss_bbox_3_unscaled: 0.0622 (0.0622)  loss_giou_3_unscaled: 0.1184 (0.1184)  cardinality_error_3_unscaled: 59.0000 (59.0000)  loss_ce_4_unscaled: 0.5131 (0.5131)  loss_bbox_4_unscaled: 0.0491 (0.0491)  loss_giou_4_unscaled: 0.1060 (0.1060)  cardinality_error_4_unscaled: 54.0000 (54.0000)  time: 1.3210  data: 0.3716  max mem: 9095
# Epoch: [42]  [3/4]  eta: 0:00:01  lr: 0.000100  class_error: 0.00  loss: 6.0189 (5.9327)  loss_ce: 0.4240 (0.4440)  loss_bbox: 0.1800 (0.2467)  loss_giou: 0.1944 (0.2380)  loss_ce_0: 0.5514 (0.5504)  loss_bbox_0: 0.2565 (0.2909)  loss_giou_0: 0.2721 (0.2821)  loss_ce_1: 0.4824 (0.5166)  loss_bbox_1: 0.2278 (0.2470)  loss_giou_1: 0.2008 (0.2259)  loss_ce_2: 0.4910 (0.4837)  loss_bbox_2: 0.3010 (0.2887)  loss_giou_2: 0.2418 (0.2333)  loss_ce_3: 0.4594 (0.4674)  loss_bbox_3: 0.2643 (0.2591)  loss_giou_3: 0.2368 (0.2419)  loss_ce_4: 0.4349 (0.4546)  loss_bbox_4: 0.2457 (0.2443)  loss_giou_4: 0.2121 (0.2181)  loss_ce_unscaled: 0.4240 (0.4440)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0360 (0.0493)  loss_giou_unscaled: 0.0972 (0.1190)  cardinality_error_unscaled: 46.0000 (48.0000)  loss_ce_0_unscaled: 0.5514 (0.5504)  loss_bbox_0_unscaled: 0.0513 (0.0582)  loss_giou_0_unscaled: 0.1361 (0.1411)  cardinality_error_0_unscaled: 55.0000 (54.2500)  loss_ce_1_unscaled: 0.4824 (0.5166)  loss_bbox_1_unscaled: 0.0456 (0.0494)  loss_giou_1_unscaled: 0.1004 (0.1130)  cardinality_error_1_unscaled: 51.0000 (52.2500)  loss_ce_2_unscaled: 0.4910 (0.4837)  loss_bbox_2_unscaled: 0.0602 (0.0577)  loss_giou_2_unscaled: 0.1209 (0.1166)  cardinality_error_2_unscaled: 54.0000 (55.0000)  loss_ce_3_unscaled: 0.4594 (0.4674)  loss_bbox_3_unscaled: 0.0529 (0.0518)  loss_giou_3_unscaled: 0.1184 (0.1209)  cardinality_error_3_unscaled: 52.0000 (54.0000)  loss_ce_4_unscaled: 0.4349 (0.4546)  loss_bbox_4_unscaled: 0.0491 (0.0489)  loss_giou_4_unscaled: 0.1060 (0.1091)  cardinality_error_4_unscaled: 49.0000 (50.7500)  time: 1.0043  data: 0.0984  max mem: 9095
# Epoch: [42] Total time: 0:00:04 (1.0238 s / it)
# Averaged stats: lr: 0.000100  class_error: 0.00  loss: 6.0189 (5.9327)  loss_ce: 0.4240 (0.4440)  loss_bbox: 0.1800 (0.2467)  loss_giou: 0.1944 (0.2380)  loss_ce_0: 0.5514 (0.5504)  loss_bbox_0: 0.2565 (0.2909)  loss_giou_0: 0.2721 (0.2821)  loss_ce_1: 0.4824 (0.5166)  loss_bbox_1: 0.2278 (0.2470)  loss_giou_1: 0.2008 (0.2259)  loss_ce_2: 0.4910 (0.4837)  loss_bbox_2: 0.3010 (0.2887)  loss_giou_2: 0.2418 (0.2333)  loss_ce_3: 0.4594 (0.4674)  loss_bbox_3: 0.2643 (0.2591)  loss_giou_3: 0.2368 (0.2419)  loss_ce_4: 0.4349 (0.4546)  loss_bbox_4: 0.2457 (0.2443)  loss_giou_4: 0.2121 (0.2181)  loss_ce_unscaled: 0.4240 (0.4440)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0360 (0.0493)  loss_giou_unscaled: 0.0972 (0.1190)  cardinality_error_unscaled: 46.0000 (48.0000)  loss_ce_0_unscaled: 0.5514 (0.5504)  loss_bbox_0_unscaled: 0.0513 (0.0582)  loss_giou_0_unscaled: 0.1361 (0.1411)  cardinality_error_0_unscaled: 55.0000 (54.2500)  loss_ce_1_unscaled: 0.4824 (0.5166)  loss_bbox_1_unscaled: 0.0456 (0.0494)  loss_giou_1_unscaled: 0.1004 (0.1130)  cardinality_error_1_unscaled: 51.0000 (52.2500)  loss_ce_2_unscaled: 0.4910 (0.4837)  loss_bbox_2_unscaled: 0.0602 (0.0577)  loss_giou_2_unscaled: 0.1209 (0.1166)  cardinality_error_2_unscaled: 54.0000 (55.0000)  loss_ce_3_unscaled: 0.4594 (0.4674)  loss_bbox_3_unscaled: 0.0529 (0.0518)  loss_giou_3_unscaled: 0.1184 (0.1209)  cardinality_error_3_unscaled: 52.0000 (54.0000)  loss_ce_4_unscaled: 0.4349 (0.4546)  loss_bbox_4_unscaled: 0.0491 (0.0489)  loss_giou_4_unscaled: 0.1060 (0.1091)  cardinality_error_4_unscaled: 49.0000 (50.7500)
# Epoch: [43]  [0/4]  eta: 0:00:04  lr: 0.000100  class_error: 0.00  loss: 5.7925 (5.7925)  loss_ce: 0.4313 (0.4313)  loss_bbox: 0.2768 (0.2768)  loss_giou: 0.1908 (0.1908)  loss_ce_0: 0.5472 (0.5472)  loss_bbox_0: 0.2667 (0.2667)  loss_giou_0: 0.2892 (0.2892)  loss_ce_1: 0.4979 (0.4979)  loss_bbox_1: 0.2340 (0.2340)  loss_giou_1: 0.3052 (0.3052)  loss_ce_2: 0.4510 (0.4510)  loss_bbox_2: 0.2116 (0.2116)  loss_giou_2: 0.2849 (0.2849)  loss_ce_3: 0.4233 (0.4233)  loss_bbox_3: 0.2626 (0.2626)  loss_giou_3: 0.2306 (0.2306)  loss_ce_4: 0.4160 (0.4160)  loss_bbox_4: 0.2605 (0.2605)  loss_giou_4: 0.2129 (0.2129)  loss_ce_unscaled: 0.4313 (0.4313)  class_error_unscaled: 0.0000 (0.0000)  loss_bbox_unscaled: 0.0554 (0.0554)  loss_giou_unscaled: 0.0954 (0.0954)  cardinality_error_unscaled: 50.0000 (50.0000)  loss_ce_0_unscaled: 0.5472 (0.5472)  loss_bbox_0_unscaled: 0.0533 (0.0533)  loss_giou_0_unscaled: 0.1446 (0.1446)  cardinality_error_0_unscaled: 53.0000 (53.0000)  loss_ce_1_unscaled: 0.4979 (0.4979)  loss_bbox_1_unscaled: 0.0468 (0.0468)  loss_giou_1_unscaled: 0.1526 (0.1526)  cardinality_error_1_unscaled: 53.0000 (53.0000)  loss_ce_2_unscaled: 0.4510 (0.4510)  loss_bbox_2_unscaled: 0.0423 (0.0423)  loss_giou_2_unscaled: 0.1425 (0.1425)  cardinality_error_2_unscaled: 48.0000 (48.0000)  loss_ce_3_unscaled: 0.4233 (0.4233)  loss_bbox_3_unscaled: 0.0525 (0.0525)  loss_giou_3_unscaled: 0.1153 (0.1153)  cardinality_error_3_unscaled: 54.0000 (54.0000)  loss_ce_4_unscaled: 0.4160 (0.4160)  loss_bbox_4_unscaled: 0.0521 (0.0521)  loss_giou_4_unscaled: 0.1065 (0.1065)  cardinality_error_4_unscaled: 53.0000 (53.0000)  time: 1.2317  data: 0.2782  max mem: 9095

# %%
import torchvision.transforms as T
import numpy as np

invTrans = T.Compose([ T.Normalize(mean = [ 0., 0., 0. ],
                                                     std = [ 1/0.229, 1/0.224, 1/0.225 ]),
                                T.Normalize(mean = [ -0.485, -0.456, -0.406 ],
                                                     std = [ 1., 1., 1. ]),
                               ])

img1 = invTrans(samples.tensors)
print(img1.shape)
print(img1[0].permute(1,2,0).shape)
img = img1[0].permute(1,2,0).cpu()
# ([0.485, 0.456, 0.406], [0.229, 0.224, 0.225])

print(img.max(), img.min())
img_cv = np.array(img*255).astype(np.uint8)
im_rgb = cv2.cvtColor(img_cv, cv2.COLOR_BGR2RGB)
cv2.imwrite('sample.png', im_rgb)
